# %% [markdown]
# ## Import Libraries

# %%
import requests
import pandas as pd
from prettytable import PrettyTable
import json

# %% [markdown]
# ## Create pretty table object

# %%
tableobj = PrettyTable()

# %% [markdown]
# ## Store API Key in a variable & concatenate it with API endpoint

# %%
KeyVal = '37d0d5d1-eca3-4739-8723-8b4dce81be2b'

api_endpoint = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY='
api_endpoint += KeyVal
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=37d0d5d1-eca3-4739-8723-8b4dce81be2b'

# %% [markdown]
# ## Fetch data in JSON format

# %%
json_data = requests.get(api_endpoint).json()
cryptodata = json_data['data']

# %%
requests.get(api_endpoint).json()
# Out:
# {'data': [{'circulating_supply': 17660237,   'cmc_rank': 1,   'date_added': '2013-04-28T00:00:00.000Z',   'id': 1,   'last_updated': '2019-04-22T23:47:27.000Z',   'max_supply': 21000000,   'name': 'Bitcoin',   'num_market_pairs': 7301,   'platform': None,   'quote': {'USD': {'last_updated': '2019-04-22T23:47:27.000Z',     'market_cap': 95313420306.7183,     'percent_change_1h': -0.317202,     'percent_change_24h': 1.69057,     'percent_change_7d': 6.47191,     'price': 5397.06348826,     'volume_24h': 14597789543.2224}},   'slug': 'bitcoin',   'symbol': 'BTC',   'tags': ['mineable'],   'total_supply': 17660237},  {'circulating_supply': 105770449.1241,   'cmc_rank': 2,   'date_added': '2015-08-07T00:00:00.000Z',   'id': 1027,   'last_updated': '2019-04-22T23:47:19.000Z',   'max_supply': None,   'name': 'Ethereum',   'num_market_pairs': 5232,   'platform': None,   'quote': {'USD': {'last_updated': '2019-04-22T23:47:19.000Z',     'market_cap': 18187965664.19498,     'percent_change_1h': -0.500194,     'percent_change_24h': 1.1542,     'percent_change_7d': 6.45466,     'price': 171.956967327,     'volume_24h': 6088591934.37358}},   'slug': 'ethereum',   'symbol': 'ETH',   'tags': ['mineable'],   'total_supply': 105770449.1241},  {'circulating_supply': 42004966728,   'cmc_rank': 3,   'date_added': '2013-08-04T00:00:00.000Z',   'id': 52,   'last_updated': '2019-04-22T23:47:04.000Z',   'max_supply': 100000000000,   'name': 'XRP',   'num_market_pairs': 383,   'platform': None,   'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',     'market_cap': 13612874990.1434,     'percent_change_1h': -0.33575,     'percent_change_24h': 0.699444,     'percent_change_7d': 1.1696,     'price': 0.324077747241,     'volume_24h': 1131457498.66725}},   'slug': 'ripple',   'symbol': 'XRP',   'tags': [],   'total_supply': 99991643723},  {'circulating_supply': 17743037.5,   'cmc_rank': 4,   'date_added': '2017-07-23T00:00:00.000Z',   'id': 1831,   'last_updated': '2019-04-22T23:47:05.000Z',   'max_supply': 21000000,   'name': 'Bitcoin Cash',   'num_market_pairs': 291,   'platform': None,   'quote': {'USD': {'last_updated': '2019-04-22T23:47:05.000Z',     'market_cap': 5203148753.219788,     'percent_change_1h': -0.55809,     'percent_change_24h': 0.999014,     'percent_change_7d': -6.30973,     'price': 293.250169438,     'volume_24h': 1186256786.11166}},   'slug': 'bitcoin-cash',   'symbol': 'BCH',   'tags': ['mineable'],   'total_supply': 17743037.5},  {'circulating_supply': 942750386.9502,   'cmc_rank': 5,   'date_added': '2017-07-01T00:00:00.000Z',   'id': 1765,   'last_updated': '2019-04-22T23:47:04.000Z',   'max_supply': None,   'name': 'EOS',   'num_market_pairs': 302,   'platform': None,   'quote': {'USD': {'last_updated': '2019-04-22T23:47:04.000Z',     'market_cap': 4950573430.946012,     'percent_change_1h': -0.620616,     'percent_change_24h': 0.380082,     'percent_change_7d': -2.05882,     'price': 5.25120275682,     'volume_24h': 1905929053.11266}},   'slug': 'eos',   'symbol': 'EOS',   'tags': [],   'total_supply': 1042750390.6093},  {'circulating_supply': 61457133.5909222,   'cmc_rank': 6,   'date_added': '2013-04-28T00:00:00.000Z',   'id': 2,   'last_updated': '2019-04-22T23:47:03.000Z',   'max_supply': 84000000,   'name': 'Litecoin',   'num_market_pairs': 554,   'platform': None,   'quote': {'USD': {'last_updated': '2019-04-22T23:47:03.000Z',     'market_cap': 4730458873.017418,     'percent_change_1h': -0.604737,     'percent_change_24h': -0.0179831,     'percent_change_7d': -2.06719,     'price': 76.9716808549,     'volume_24h': 2661905447.47869}},   'slug': 'litecoin',   'symbol': 'LTC',   'tags': ['mineable'],   'total_supply': 61457133.5909222},  {'circulating_supply': 141175490.242,   'cmc_rank': 7,   'date_added': '2017-07-25T00:00:00.000Z',   'id': 1839,   'last_updated': '2019-04-22T23:47:04.000Z',   'max_supply': None,   'name': 'Binance Coin',   'num_market_pairs': 147,   'platform': {'id': 1027,    'name': 'Ethereu ...

# %% [markdown]
# ## Store data in Pretty Table

# %%
for currency in cryptodata:
    curr_name = currency['name']
    curr_price = currency['quote']['USD']['price']
    curr_change_1h = currency['quote']['USD']['percent_change_1h']
    curr_change_24h = currency['quote']['USD']['percent_change_24h']
    curr_change_7d = currency['quote']['USD']['percent_change_7d']
    tableobj.add_row([curr_name, curr_price, curr_change_1h, curr_change_24h, curr_change_7d])

# %% [markdown]
# ## Create External Field names and assign as column names in Pretty table

# %%
tableobj.field_names =  ["Currency Name", "Currency Price", "Currency 1h Change", "Currency 24h change", "Currency 7d change"]

# %%
tableobj
# Out:
# +-----------------------+-------------------+--------------------+---------------------+--------------------+|     Currency Name     |   Currency Price  | Currency 1h Change | Currency 24h change | Currency 7d change |+-----------------------+-------------------+--------------------+---------------------+--------------------+|        Bitcoin        |   5395.93482863   |     -0.301241      |       1.67833       |      6.45182       ||        Ethereum       |   171.679679233   |     -0.625783      |       1.00709       |      6.29453       ||          XRP          |   0.323826259932  |     -0.338398      |       0.631114      |      1.09363       ||      Bitcoin Cash     |   293.223052743   |     -0.500709      |       1.04336       |      -6.30347      ||          EOS          |   5.24829958966   |     -0.663814      |       0.354616      |      -2.10802      ||        Litecoin       |    77.010881659   |     -0.540749      |      0.0512766      |      -2.01171      ||      Binance Coin     |   23.9180267057   |      1.23429       |      -0.876029      |      25.1995       ||         Tether        |    1.0066692901   |     0.0122913      |      0.0514391      |      0.477698      ||        Stellar        |   0.113510122924  |     -0.407042      |       1.17453       |     -0.158736      ||        Cardano        |   0.078328552124  |     -0.202013      |       5.94131       |      -4.49479      ||          TRON         |  0.0251768797514  |      -0.11395      |       0.661038      |      -4.66225      ||         Monero        |   68.5850900392   |     -0.439058      |      0.0814216      |      6.20146       ||          Dash         |   122.623185733   |     -0.215139      |       0.932616      |      3.50391       ||       Bitcoin SV      |   57.7320918097   |      -1.05453      |       2.02989       |      -2.33204      ||         Tezos         |   1.34485384103   |     -0.295701      |       1.22089       |      25.5726       ||          IOTA         |   0.309887386353  |     -0.020932      |       1.26663       |       1.8617       ||          NEO          |   10.8219875674   |     -0.496782      |       2.77108       |      0.943441      ||    Ethereum Classic   |   5.94200683493   |     -0.368996      |       0.477218      |      -3.60662      ||        Ontology       |   1.23671503213   |      0.439603      |       0.54443       |      -4.37433      ||         Maker         |    606.92259523   |     -0.261892      |       0.506255      |      -3.84341      ||          NEM          |  0.0640887182307  |      -0.39575      |       1.31256       |      -1.0292       || Basic Attention Token |    0.3981570912   |     -0.637878      |       -11.0222      |      35.2271       ||         Zcash         |   69.1191339374   |     -0.201401      |       1.12907       |      3.08441       ||    Crypto.com Chain   |  0.0816901512349  |       1.5627       |       -1.72098      |      4.87336       ||        VeChain        |  0.0069982237727  |    -0.00714884     |       2.70428       |      2.78171       ||        Dogecoin       |  0.00280019457838 |      -0.35626      |       1.56876       |      0.212099      ||      Bitcoin Gold     |   16.9397232967   |     -0.527219      |       1.58411       |       3.4235       ||         Waves         |   2.63420406348   |     -0.375385      |       1.08876       |     0.0584478      ||        OmiseGO        |    1.8736185956   |     -0.174754      |       0.690785      |      0.799532      ||        USD Coin       |   1.00418649464   |     -0.0834506     |       0.252437      |      0.36061       ||         Augur         |   22.7917184467   |      1.63758       |       9.52372       |       20.345       ||         Decred        |   25.6377773348   |     -0.184575      |       0.94828       |      6.12032       ||          Qtum         |    2.7641105848   |     -0.523838      |        1.8344       |      -2.49351      ||          Nano         |   1.76693619808   |      0.239493      |       5.0 ...

# %% [markdown]
# ## Store data in Text File format

# %%
table_txt = tableobj.get_string()
with open('output.txt', 'w') as file:
    file.write(table_txt)
